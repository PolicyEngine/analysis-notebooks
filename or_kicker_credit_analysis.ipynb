# %% [markdown]
# # Oregon Kicker Credit Analysis (2024)
#
# This notebook analyzes the impact of applying the 2025 Oregon kicker rate to tax year 2024:
# - **Baseline**: Current law for 2024 (0% kicker rate)
# - **Reform**: 2025 kicker rate (9.86%) applied to 2024
#
# The Oregon kicker is a tax refund provided to taxpayers when state revenues exceed forecasts.
#
# **Note**: Since the kicker is based on prior-year tax liability (`or_tax_before_credits_in_prior_year`), which is an input variable not present in the dataset, we inject current-year tax as a proxy to enable the analysis.

# %%
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setup Simulations
#
# The baseline is current law for 2024 (0% kicker), while the reform applies the 2025 kicker rate.

# %%
DATASET = "hf://policyengine/policyengine-us-data/states/OR.h5"
YEAR = 2024
KICKER_RATE_2025 = 0.09863  # 9.86%

# Step 1: Run initial simulation to get current-year tax before credits
# (used as proxy for prior-year tax)
initial_sim = Microsimulation(dataset=DATASET)
tax_before_credits = initial_sim.calculate("or_income_tax_before_credits", period=YEAR)

print(f"Calculated OR tax before credits for {YEAR}:")
print(f"  Mean: ${tax_before_credits.mean():.2f}")
print(f"  Max: ${tax_before_credits.max():.2f}")
# Out:
# Calculated OR tax before credits for 2024:
#   Mean: $6478.82
#   Max: $43349792.00

# %%
# Step 2: Create simulations with prior-year tax injected
# Reform that applies the 2025 kicker rate to 2024
kicker_reform = Reform.from_dict({
    "gov.states.or.tax.income.credits.kicker.percent": {
        "2024-01-01.2100-12-31": KICKER_RATE_2025
    }
}, country_id="us")

# Baseline: Current law for 2024 (0% kicker)
baseline = Microsimulation(dataset=DATASET)

# Reform: 2025 kicker rate (9.86%) applied to 2024
reformed = Microsimulation(reform=kicker_reform, dataset=DATASET)

# Inject prior-year tax values (using current year as proxy)
baseline.set_input("or_tax_before_credits_in_prior_year", YEAR, tax_before_credits.values)
reformed.set_input("or_tax_before_credits_in_prior_year", YEAR, tax_before_credits.values)

# Check the kicker percent parameters
params_baseline = baseline.tax_benefit_system.parameters
params_reformed = reformed.tax_benefit_system.parameters
kicker_param_baseline = getattr(getattr(getattr(getattr(getattr(getattr(params_baseline.gov.states, "or"), "tax"), "income"), "credits"), "kicker"), "percent")
kicker_param_reformed = getattr(getattr(getattr(getattr(getattr(getattr(params_reformed.gov.states, "or"), "tax"), "income"), "credits"), "kicker"), "percent")
print(f"Baseline kicker percent for {YEAR}: {kicker_param_baseline(f'{YEAR}-01-01') * 100:.2f}%")
print(f"Reform kicker percent for {YEAR}: {kicker_param_reformed(f'{YEAR}-01-01') * 100:.2f}%")
# Out:
# Baseline kicker percent for 2024: 0.00%
# Reform kicker percent for 2024: 9.86%

# %% [markdown]
# ## Household Net Income Impact

# %%
baseline_income = baseline.calculate("household_net_income", period=YEAR)
reformed_income = reformed.calculate("household_net_income", period=YEAR)

income_change = reformed_income - baseline_income

# MicroSeries already has weights, so just use .sum() directly
total_income_change = income_change.sum()
print(f"Total change in household net income: ${total_income_change / 1e9:.2f} billion")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 baseline_income = baseline.calculate("household_net_income", period=YEAR)
# ----> 2 reformed_income = reformed.calculate("household_net_income", period=YEAR)
#       4 income_change = reformed_income - baseline_income
#       6 # MicroSeries already has weights, so just use .sum() directly
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:946, in Simulation._run_formula(self, variable, population, period)
#     944 for added_variable in adds_list:
#     945     if added_variable in self.tax_benefit_system.variables:
# --> 946         values = values + self.calculate(
#     947             added_variable, period, map_to=variable.entity.key
#     948         )
#     949     else:
#     950         try:
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:946, in Simulation._run_formula(self, variable, population, period)
#     944 for added_variable in adds_list:
#     945     if added_variable in self.tax_benefit_system.variables:
# --> 946         values = values + self.calculate(
#     947             added_variable, period, map_to=variable.entity.key
#     948         )
#     949     else:
#     950         try:
#
#     [... skipping similar frames: Simulation._calculate at line 721 (1 times), Microsimulation.calculate at line 54 (1 times), Simulation.calculate at line 491 (1 times)]
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:946, in Simulation._run_formula(self, variable, population, period)
#     944 for added_variable in adds_list:
#     945     if added_variable in self.tax_benefit_system.variables:
# --> 946         values = values + self.calculate(
#     947             added_variable, period, map_to=variable.entity.key
#     948         )
#     949     else:
#     950         try:
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\credits\ctc\refundable\refundable_ctc.py:34, in refundable_ctc.formula(tax_unit, period, parameters)
#      31 maximum_refundable_ctc = min_(maximum_amount, total_ctc)
#      33 phase_in = tax_unit("ctc_phase_in", period)
# ---> 34 limiting_tax = tax_unit("ctc_limiting_tax_liability", period)
#      35 ctc_capped_by_tax = min_(total_ctc, limiting_tax)
#      36 ctc_capped_by_increased_tax = min_(total_ctc, limiting_tax + phase_in)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\credits\ctc\refundable\ctc_limiting_tax_liability.py:16, in ctc_limiting_tax_liability.formula(tax_unit, period, parameters)
#      14 no_salt_branch = simulation.get_branch("no_salt")
#      15 no_salt_branch.set_input("salt_deduction", period, np.zeros(tax_unit.count))
# ---> 16 tax_liability_before_credits = no_salt_branch.calculate(
#      17     "income_tax_before_credits", period
#      18 )
#      19 non_refundable_credits = parameters(period).gov.irs.credits.non_refundable
#      20 non_refundable_credits_ex_ctc = [
#      21     x for x in non_refundable_credits if x != "non_refundable_ctc"
#      22 ]
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:946, in Simulation._run_formula(self, variable, population, period)
#     944 for added_variable in adds_list:
#     945     if added_variable in self.tax_benefit_system.variables:
# --> 946         values = values + self.calculate(
#     947             added_variable, period, map_to=variable.entity.key
#     948         )
#     949     else:
#     950         try:
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\before_credits\income_tax_main_rates.py:14, in income_tax_main_rates.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
#      13     # compute taxable income that is taxed at the main rates
# ---> 14     full_taxable_income = tax_unit("taxable_income", period)
#      15     cg_exclusion = tax_unit("capital_gains_excluded_from_taxable_income", period)
#      16     taxinc = max_(0, full_taxable_income - cg_exclusion)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\taxable_income.py:14, in taxable_income.formula(tax_unit, period, parameters)
#      12 agi = tax_unit("adjusted_gross_income", period)
#      13 exemptions = tax_unit("exemptions", period)
# ---> 14 deductions = tax_unit("taxable_income_deductions", period)
#      15 return max_(0, agi - exemptions - deductions)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\deductions\taxable_income_deductions.py:12, in taxable_income_deductions.formula(tax_unit, period, parameters)
#      11 def formula(tax_unit, period, parameters):
# ---> 12     itemizes = tax_unit("tax_unit_itemizes", period)
#      13     deductions_if_itemizing = tax_unit(
#      14         "taxable_income_deductions_if_itemizing", period
#      15     )
#      16     deductions_if_not_itemizing = tax_unit(
#      17         "taxable_income_deductions_if_not_itemizing", period
#      18     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\deductions\tax_unit_itemizes.py:17, in tax_unit_itemizes.formula(tax_unit, period, parameters)
#      14 if parameters(period).gov.simulation.branch_to_determine_itemization:
#      15     # determine federal itemization behavior by comparing tax liability
#      16     tax_liability_if_itemizing = tax_unit("tax_liability_if_itemizing", period)
# ---> 17     tax_liability_if_not_itemizing = tax_unit(
#      18         "tax_liability_if_not_itemizing", period
#      19     )
#      20     state_standard_deduction = tax_unit("state_standard_deduction", period)
#      21     state_itemized_deductions = tax_unit("state_itemized_deductions", period)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\deductions\tax_liability_if_not_itemizing.py:20, in tax_liability_if_not_itemizing.formula(tax_unit, period, parameters)
#      14 non_itemized_branch = simulation.get_branch("not_itemizing")
#      15 non_itemized_branch.set_input(
#      16     "tax_unit_itemizes",
#      17     period,
#      18     np.zeros((tax_unit.count,), dtype=bool),
#      19 )
# ---> 20 return non_itemized_branch.calculate("income_tax", period)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\income_tax.py:18, in income_tax.formula(person, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         person, period, ["income_tax_before_refundable_credits"]
#      20     )
#      21     subtracted_components = add(
#      22         person, period, ["income_tax_refundable_credits"]
#      23     )
#      24     return added_components - subtracted_components
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\commons\formulas.py:232, in add(entity, period, variables, options)
#     212 def add(
#     213     entity: Population,
#     214     period: Period,
#     215     variables: List[str],
#     216     options: List[str] = None,
#     217 ):
#     218     """Sums a list of variables.
#     219
#     220     Args:
#    (...)
#     230         ArrayLike: The result of the operation.
#     231     """
# --> 232     return for_each_variable(
#     233         entity, period, variables, agg_func="add", options=options
#     234     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\commons\formulas.py:188, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     186 variable_entity = entity.entity.get_variable(variable).entity
#     187 if variable_entity.key == entity.entity.key:
# --> 188     values = entity(variable, period, options=options)
#     189 elif variable_entity.is_person:
#     190     values = group_agg_func(
#     191         entity.members(variable, period, options=options)
#     192     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\income_tax_before_refundable_credits.py:18, in income_tax_before_refundable_credits.formula(tax_unit, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         tax_unit,
#      20         period,
#      21         [
#      22             "income_tax_before_credits",
#      23             "net_investment_income_tax",
#      24             "recapture_of_investment_credit",
#      25             "unreported_payroll_tax",
#      26             "qualified_retirement_penalty",
#      27         ],
#      28     )
#      29     subtracted_components = add(
#      30         tax_unit, period, ["income_tax_capped_non_refundable_credits"]
#      31     )
#      32     return added_components - subtracted_components
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\commons\formulas.py:232, in add(entity, period, variables, options)
#     212 def add(
#     213     entity: Population,
#     214     period: Period,
#     215     variables: List[str],
#     216     options: List[str] = None,
#     217 ):
#     218     """Sums a list of variables.
#     219
#     220     Args:
#    (...)
#     230         ArrayLike: The result of the operation.
#     231     """
# --> 232     return for_each_variable(
#     233         entity, period, variables, agg_func="add", options=options
#     234     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\commons\formulas.py:188, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     186 variable_entity = entity.entity.get_variable(variable).entity
#     187 if variable_entity.key == entity.entity.key:
# --> 188     values = entity(variable, period, options=options)
#     189 elif variable_entity.is_person:
#     190     values = group_agg_func(
#     191         entity.members(variable, period, options=options)
#     192     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\populations\population.py:142, in Population.__call__(self, variable_name, period, options)
#     138     return self.simulation.calculate_divide(
#     139         variable_name, period, **calculate_kwargs
#     140     )
#     141 else:
# --> 142     return self.simulation.calculate(
#     143         variable_name, period, **calculate_kwargs
#     144     )
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:946, in Simulation._run_formula(self, variable, population, period)
#     944 for added_variable in adds_list:
#     945     if added_variable in self.tax_benefit_system.variables:
# --> 946         values = values + self.calculate(
#     947             added_variable, period, map_to=variable.entity.key
#     948         )
#     949     else:
#     950         try:
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:491, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     488 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     490 try:
# --> 491     result = self._calculate(variable_name, period)
#     492     if isinstance(result, EnumArray) and decode_enums:
#     493         result = result.decode_to_str()
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:721, in Simulation._calculate(self, variable_name, period)
#     719 try:
#     720     self._check_for_cycle(variable.name, period)
# --> 721     array = self._run_formula(variable, population, period)
#     723     # If no result, use the default value and cache it
#     724     if array is None:
#     725         # Check if the variable has a previously defined value
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\simulations\simulation.py:1011, in Simulation._run_formula(self, variable, population, period)
#    1009     array = formula(population, period)
#    1010 else:
# -> 1011     array = formula(population, period, parameters_at)
#    1013 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\capital_gains\capital_gains_tax.py:28, in capital_gains_tax.formula(tax_unit, period, parameters)
#      24 income_less_ancg = max_(0, taxable_income - adjusted_net_cg)
#      26 filing_status = tax_unit("filing_status", period)
# ---> 28 first_threshold = cg.thresholds["1"][filing_status]
#      29 second_threshold = cg.thresholds["2"][filing_status]
#      31 income_ordinarily_under_second_rate = clip(taxable_income, 0, first_threshold)
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\parameters\parameter_node_at_instant.py:62, in ParameterNodeAtInstant.__getitem__(self, key)
#      60     key = numpy.asarray(key)
#      61 if isinstance(key, numpy.ndarray):
# ---> 62     return parameters.VectorialParameterNodeAtInstant.build_from_node(
#      63         self
#      64     )[key]
#      65 return self._children[key]
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\policyengine_core\parameters\vectorial_parameter_node_at_instant.py:214, in VectorialParameterNodeAtInstant.__getitem__(self, key)
#     212 elif isinstance(key, EnumArray):
#     213     enum = key.possible_values
# --> 214     key = numpy.select(
#     215         [key == item.index for item in enum],
#     216         [item.name for item in enum],
#     217         default="unknown",
#     218     )
#     219 else:
#     220     key = key.astype("str")
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\_function_base_impl.py:907, in select(condlist, choicelist, default)
#     904 else:
#     905     result_shape = np.broadcast_arrays(condlist[0], choicelist[0])[0].shape
# --> 907 result = np.full(result_shape, choicelist[-1], dtype)
#     909 # Use np.copyto to burn each choicelist array onto result, using the
#     910 # corresponding condlist as a boolean mask. This is done in reverse
#     911 # order since the first choice should take precedence.
#     912 choicelist = choicelist[-2::-1]
#
# File c:\Users\dtsax\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\numeric.py:385, in full(shape, fill_value, dtype, order, device, like)
#     383     fill_value = asarray(fill_value)
#     384     dtype = fill_value.dtype
# --> 385 a = empty(shape, dtype, order, device=device)
#     386 multiarray.copyto(a, fill_value, casting='unsafe')
#     387 return a
#
# MemoryError: Unable to allocate 2.88 MiB for an array with shape (44451,) and data type <U17

# %% [markdown]
# ## Budgetary Impact

# %%
baseline_state_tax = baseline.calculate("or_income_tax", period=YEAR)
reformed_state_tax = reformed.calculate("or_income_tax", period=YEAR)

# MicroSeries already has weights
baseline_revenue = baseline_state_tax.sum()
reformed_revenue = reformed_state_tax.sum()
revenue_change = reformed_revenue - baseline_revenue

print(f"Baseline state income tax revenue (no kicker): ${baseline_revenue / 1e9:.2f} billion")
print(f"Reformed state income tax revenue (current law): ${reformed_revenue / 1e9:.2f} billion")
print(f"Revenue change (cost of kicker credit): ${revenue_change / 1e9:.2f} billion")
# Out:
# Baseline state income tax revenue (no kicker): $10.38 billion
# Reformed state income tax revenue (current law): $9.28 billion
# Revenue change (cost of kicker credit): $-1.10 billion

# %% [markdown]
# ## Kicker Credit Amount

# %%
# Calculate the kicker credit directly
kicker_credit = reformed.calculate("or_kicker", period=YEAR)
total_kicker = kicker_credit.sum()

print(f"Total kicker credit claimed: ${total_kicker / 1e9:.2f} billion")

# Handle case where there are no recipients
recipients = kicker_credit > 0
num_recipients = recipients.sum()  # Weighted count

if num_recipients > 0:
    avg_kicker = kicker_credit[recipients].mean()
    print(f"Average kicker credit (among recipients): ${avg_kicker:.2f}")
    print(f"Number of tax units receiving kicker: {num_recipients / 1e6:.2f} million")
else:
    print("No tax units received the kicker credit in this year.")
    print("This is expected if the kicker percent is 0% for the analysis year.")
# Out:
# Total kicker credit claimed: $1.10 billion
# Average kicker credit (among recipients): $932.27
# Number of tax units receiving kicker: 1.18 million

# %% [markdown]
# ## Distributional Analysis by Income Decile

# %%
# Get household-level data for distributional analysis
income_decile = baseline.calculate("household_income_decile", period=YEAR)

# Calculate change by decile
decile_data = []
for decile in range(1, 11):
    mask = income_decile == decile
    decile_change = income_change[mask].sum()
    decile_hh_count = mask.sum()  # Weighted count
    avg_change = income_change[mask].mean() if mask.any() else 0
    decile_data.append({
        "Decile": decile,
        "Total Change ($B)": decile_change / 1e9,
        "Avg Change per HH ($)": avg_change,
        "Households (M)": decile_hh_count / 1e6
    })

decile_df = pd.DataFrame(decile_data)
decile_df
# Out:
#    Decile  Total Change ($B)  Avg Change per HH ($)  Households (M)
# 0       1           0.002320              12.402648        0.187061
# 1       2           0.010797              54.775376        0.197117
# 2       3           0.015994              92.141032        0.173586
# 3       4           0.021655             129.934874        0.166657
# 4       5           0.031404             223.160114        0.140725
# 5       6           0.045777             356.026667        0.128577
# 6       7           0.049882             490.347207        0.101728
# 7       8           0.067396             746.737625        0.090253
# 8       9           0.101749            1154.969138        0.088097
# 9      10           0.744553            7101.122511        0.104850

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Total change by decile
axes[0].bar(decile_df["Decile"], decile_df["Total Change ($B)"], color="steelblue")
axes[0].set_xlabel("Income Decile")
axes[0].set_ylabel("Total Change ($B)")
axes[0].set_title("Total Income Change by Decile")
axes[0].set_xticks(range(1, 11))

# Average change by decile
axes[1].bar(decile_df["Decile"], decile_df["Avg Change per HH ($)"], color="darkgreen")
axes[1].set_xlabel("Income Decile")
axes[1].set_ylabel("Average Change per Household ($)")
axes[1].set_title("Average Income Change by Decile")
axes[1].set_xticks(range(1, 11))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Winners and Losers

# %%
winners = income_change > 1  # Gain more than $1
losers = income_change < -1  # Lose more than $1
unchanged = ~winners & ~losers

total_hh = winners.sum() + losers.sum() + unchanged.sum()  # Weighted total

print(f"Households gaining from kicker credit: {winners.sum() / total_hh * 100:.1f}%")
print(f"Households losing from kicker credit: {losers.sum() / total_hh * 100:.1f}%")
print(f"Households unchanged: {unchanged.sum() / total_hh * 100:.1f}%")

if winners.any():
    print(f"\nAverage gain among winners: ${income_change[winners].mean():.2f}")
if losers.any():
    print(f"Average loss among losers: ${income_change[losers].mean():.2f}")
# Out:
# Households gaining from kicker credit: 69.2%
# Households losing from kicker credit: 0.0%
# Households unchanged: 30.8%
#
# Average gain among winners: $1119.70

# %% [markdown]
# ## Poverty Impact

# %%
baseline_poverty = baseline.calculate("in_poverty", period=YEAR)
reformed_poverty = reformed.calculate("in_poverty", period=YEAR)

# MicroSeries .mean() gives weighted mean
baseline_poverty_rate = baseline_poverty.mean() * 100
reformed_poverty_rate = reformed_poverty.mean() * 100

print(f"Baseline poverty rate (no kicker): {baseline_poverty_rate:.2f}%")
print(f"Reformed poverty rate (with kicker): {reformed_poverty_rate:.2f}%")
print(f"Change in poverty rate: {reformed_poverty_rate - baseline_poverty_rate:.2f} pp")
# Out:
# Baseline poverty rate (no kicker): 42.95%
# Reformed poverty rate (with kicker): 42.80%
# Change in poverty rate: -0.15 pp

# %% [markdown]
# ## Summary

# %%
print("=" * 50)
print("Oregon Kicker Credit Impact Summary (2024)")
print("=" * 50)
print(f"\nApplying 2025 kicker rate ({KICKER_RATE_2025*100:.2f}%) to 2024")
print(f"\nFiscal Impact:")
print(f"  Cost to state revenue: ${-revenue_change / 1e9:.2f} billion")
print(f"\nDistributional Impact:")
print(f"  Total benefit to households: ${total_income_change / 1e9:.2f} billion")
print(f"  Share of households benefiting: {winners.sum() / total_hh * 100:.1f}%")
print(f"\nPoverty Impact:")
print(f"  Change in poverty rate: {reformed_poverty_rate - baseline_poverty_rate:.2f} pp")
