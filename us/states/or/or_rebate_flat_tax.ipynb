# %%
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform

# %%
reform = Reform.from_dict({
  "gov.contrib.ubi_center.basic_income.amount.person.flat": {
    "2025-01-01.2025-12-31": 1160,
    "2026-01-01.2026-12-31": 1605,
    "2027-01-01.2027-12-31": 1686
  },
  "gov.contrib.ubi_center.basic_income.taxable": {
    "2025-01-01.2100-12-31": True
  },

  "gov.states.or.tax.income.rates.head_of_household[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.head_of_household[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.head_of_household[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.head_of_household[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.joint[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.separate[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.single[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.widow[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  }
}, country_id="us")

reform_taxable = Reform.from_dict({
  "gov.contrib.states.or.rebate.state_tax_exempt": {
    "2025-01-01.2100-12-31": True
  },
  "gov.contrib.ubi_center.basic_income.amount.person.flat": {
    "2025-01-01.2025-12-31": 1160,
    "2026-01-01.2026-12-31": 1605,
    "2027-01-01.2027-12-31": 1686
  },
  "gov.contrib.ubi_center.basic_income.taxable": {
    "2025-01-01.2100-12-31": True
  },

  "gov.states.or.tax.income.rates.head_of_household[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.head_of_household[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.head_of_household[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.head_of_household[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.joint[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.joint[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.separate[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.separate[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.single[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.single[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[0].rate": {
    "2025-01-01.2025-12-31": 0.097,
    "2026-01-01.2026-12-31": 0.103,
    "2027-01-01.2027-12-31": 0.103,
  },
  "gov.states.or.tax.income.rates.widow[1].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[2].threshold": {
    "2025-01-01.2100-12-31": 999999
  },
  "gov.states.or.tax.income.rates.widow[3].threshold": {
    "2025-01-01.2100-12-31": 999999
  }
}, country_id="us")

# %%
# Initialize microsimulations
baseline = Microsimulation()
reformed = Microsimulation(reform=reform)
reformed_taxable = Microsimulation(reform=reform_taxable)

# %%
# Function to calculate total household net income
def calculate_total_household_net_income(simulation, year):
    state_codes = baseline.calc("state_code", map_to="household", period=year)
    mask = state_codes == "OR"
    household_net_income = simulation.calc("household_net_income", period=year)
    return household_net_income[mask].sum()

# %%
# Calculate and output the differences for each year
for year in range(2025, 2028):
    baseline_income = calculate_total_household_net_income(baseline, year)
    reform_income = calculate_total_household_net_income(reformed, year)
    reform_taxable_income = calculate_total_household_net_income(reformed_taxable, year)

    print(f"Year {year}:")
    print(f"  Baseline - Reform: ${baseline_income - reform_income:,.2f}")
    print(f"  Baseline - Reform Taxable: ${baseline_income - reform_taxable_income:,.2f}")
    print()
# Out:
# Year 2025:
#   Baseline - Reform: $54,938,758.52
#   Baseline - Reform Taxable: $54,938,758.52
#
# Year 2026:
#   Baseline - Reform: $-30,235,464.71
#   Baseline - Reform Taxable: $-30,235,464.71
#
# Year 2027:
#   Baseline - Reform: $-86,210,726.80
#   Baseline - Reform Taxable: $-86,210,726.80
