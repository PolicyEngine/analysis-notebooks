# %%
import gc
import traceback
import os
from tqdm import tqdm
import pandas as pd
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
from policyengine_us_data import Pooled_3_Year_CPS_2023

# %%
def define_reforms():
    reforms = {
        "reform": Reform.from_dict({
            "gov.contrib.ubi_center.basic_income.amount.person.flat": {
                "2025-01-01.2025-12-31": 1160,
                "2026-01-01.2026-12-31": 1605,
                "2027-01-01.2027-12-31": 1686
            }
        }, country_id="us"),

        "reform_taxable": Reform.from_dict({
            "gov.contrib.states.or.rebate.state_tax_exempt": {
                "2024-01-01.2100-12-31": True
            },
            "gov.contrib.ubi_center.basic_income.amount.person.flat": {
                "2025-01-01.2025-12-31": 1160,
                "2026-01-01.2026-12-31": 1605,
                "2027-01-01.2027-12-31": 1686
            },
            "gov.contrib.ubi_center.basic_income.taxable": {
                "2024-01-01.2100-12-31": True
            }
        }, country_id="us"),

        "reform_flat_tax": Reform.from_dict({
            "gov.contrib.ubi_center.basic_income.amount.person.flat": {
                "2025-01-01.2025-12-31": 1160,
                "2026-01-01.2026-12-31": 1605,
                "2027-01-01.2027-12-31": 1686
            },
            "gov.contrib.ubi_center.flat_tax.rate.agi": {
                "2025-01-01.2025-12-31": 0.0187,
                "2026-01-01.2026-12-31": 0.025,
                "2027-01-01.2028-12-31": 0.0254
            }
        }, country_id="us"),

        "reform_taxable_flat_tax": Reform.from_dict({
            "gov.contrib.states.or.rebate.state_tax_exempt": {
                "2024-01-01.2100-12-31": True
            },
            "gov.contrib.ubi_center.basic_income.amount.person.flat": {
                "2025-01-01.2025-12-31": 1160,
                "2026-01-01.2026-12-31": 1605,
                "2027-01-01.2027-12-31": 1686
            },
            "gov.contrib.ubi_center.basic_income.taxable": {
                "2024-01-01.2100-12-31": True
            },
            "gov.contrib.ubi_center.flat_tax.rate.agi": {
                "2025-01-01.2025-12-31": 0.0187,
                "2026-01-01.2026-12-31": 0.025,
                "2027-01-01.2028-12-31": 0.0254
            }
        }, country_id="us")
    }
    return reforms

# %%
def initialize_microsimulations(reforms):
    baseline = Microsimulation(dataset=Pooled_3_Year_CPS_2023)
    reformed_sims = {name: Microsimulation(reform=reform, dataset=Pooled_3_Year_CPS_2023) 
                     for name, reform in reforms.items()}
    return baseline, reformed_sims

# %%
def calculate_poverty_impact_for_age_group(baseline, reformed, year, min_age, max_age, label):
    try:
        state_codes = baseline.calc("state_code", map_to="person", period=year)
        age = baseline.calc("age", map_to="person", period=year)
        baseline_poverty = baseline.calc("in_poverty", map_to="person", period=year)
        reform_poverty = reformed.calc("in_poverty", map_to="person", period=year)

        mask = (state_codes == "OR") & (age >= min_age) & (age < max_age) if label != "Overall" else (state_codes == "OR")
        baseline_poverty_group = baseline_poverty[mask].mean()
        reform_poverty_group = reform_poverty[mask].mean()
        relative_poverty_reduction = (reform_poverty_group - baseline_poverty_group) / baseline_poverty_group

        return relative_poverty_reduction
    except Exception as e:
        print(f"Error calculating poverty impact for age group {label} in year {year}: {str(e)}")
        traceback.print_exc()
        return None

# %%
def process_age_group(year, baseline, reformed, reform_name, min_age, max_age, label):
    try:
        relative_poverty_reduction = calculate_poverty_impact_for_age_group(baseline, reformed, year, min_age, max_age, label)
        if relative_poverty_reduction is not None:
            result = {
                "year": year,
                "age_group": label,
                "reform": reform_name,
                "relative_poverty_reduction": relative_poverty_reduction
            }
            checkpoint_path = f"or_rebate_{year}_{reform_name}_{label.replace('-', '_')}.csv"
            pd.DataFrame([result]).to_csv(checkpoint_path, index=False)
            print(f"Results for year {year}, reform {reform_name}, age group {label} saved to {checkpoint_path}")
            return result
        return None
    except Exception as e:
        print(f"Error processing age group {label} for year {year} and reform {reform_name}: {str(e)}")
        traceback.print_exc()
        return None

# %%
def get_processed_combinations(start_year, end_year, reforms):
    processed = set()
    for year in range(start_year, end_year):
        for reform_name in reforms.keys():
            for label in ["0-17", "18-64", "65+", "Overall"]:
                file_name = f"or_rebate_{year}_{reform_name}_{label.replace('-', '_')}.csv"
                if os.path.exists(file_name):
                    processed.add((year, reform_name, label))
    return processed

# %%
if __name__ == "__main__":
    try:
        reforms = define_reforms()
        baseline, reformed_sims = initialize_microsimulations(reforms)
        print("Microsimulations initialized.")

        start_year = 2025
        end_year = 2028
        age_groups = [
            (0, 18, "0-17"),
            (18, 65, "18-64"),
            (65, 200, "65+"),
            (0, 200, "Overall")
        ]

        processed_combinations = get_processed_combinations(start_year, end_year, reforms)
        
        all_results = []
        for year in tqdm(range(start_year, end_year), desc="Processing years"):
            for reform_name, reformed in reformed_sims.items():
                for min_age, max_age, label in age_groups:
                    if (year, reform_name, label) not in processed_combinations:
                        result = process_age_group(year, baseline, reformed, reform_name, min_age, max_age, label)
                        if result:
                            all_results.append(result)
                    else:
                        print(f"Skipping already processed: Year {year}, Reform {reform_name}, Age group {label}")
                        file_name = f"or_rebate_{year}_{reform_name}_{label.replace('-', '_')}.csv"
                        all_results.append(pd.read_csv(file_name).iloc[0].to_dict())
            
            # Clear some memory after each year
            gc.collect()

        final_results = pd.DataFrame(all_results)
        final_csv_path = "or_rebate_all_results.csv"
        final_results.to_csv(final_csv_path, index=False)
        print(f"All results saved to {final_csv_path}")
    except Exception as e:
        print(f"An error occurred in the main execution: {str(e)}")
        traceback.print_exc()
# Out:
# Microsimulations initialized.
# Processing years:   0%|          | 0/3 [00:50<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      21 for min_age, max_age, label in age_groups:
#      22     if (year, reform_name, label) not in processed_combinations:
# ---> 23         result = process_age_group(year, baseline, reformed, reform_name, min_age, max_age, label)
#      24         if result:
#      25             all_results.append(result)
#
# Cell In[5], line 3, in process_age_group(year, baseline, reformed, reform_name, min_age, max_age, label)
#       1 def process_age_group(year, baseline, reformed, reform_name, min_age, max_age, label):
#       2     try:
# ----> 3         relative_poverty_reduction = calculate_poverty_impact_for_age_group(baseline, reformed, year, min_age, max_age, label)
#       4         if relative_poverty_reduction is not None:
#       5             result = {
#       6                 "year": year,
#       7                 "age_group": label,
#       8                 "reform": reform_name,
#       9                 "relative_poverty_reduction": relative_poverty_reduction
#      10             }
#
# Cell In[4], line 6, in calculate_poverty_impact_for_age_group(baseline, reformed, year, min_age, max_age, label)
#       4 age = baseline.calc("age", map_to="person", period=year)
#       5 baseline_poverty = baseline.calc("in_poverty", map_to="person", period=year)
# ----> 6 reform_poverty = reformed.calc("in_poverty", map_to="person", period=year)
#       8 mask = (state_codes == "OR") & (age >= min_age) & (age < max_age) if label != "Overall" else (state_codes == "OR")
#       9 baseline_poverty_group = baseline_poverty[mask].mean()
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/household/income/spm_unit/in_poverty.py:12, in in_poverty.formula(spm_unit, period, parameters)
#      11 def formula(spm_unit, period, parameters):
# ---> 12     return spm_unit("poverty_gap", period) > 0
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/household/income/spm_unit/poverty_gap.py:13, in poverty_gap.formula(spm_unit, period, parameters)
#      12 def formula(spm_unit, period, parameters):
# ---> 13     income = spm_unit("spm_unit_net_income", period)
#      14     poverty_threshold = spm_unit("spm_unit_spm_threshold", period)
#      15     return max_(poverty_threshold - income, 0)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:903, in Simulation._run_formula(self, variable, population, period)
#     901 for added_variable in adds_list:
#     902     if added_variable in self.tax_benefit_system.variables:
# --> 903         values = values + self.calculate(
#     904             added_variable, period, map_to=variable.entity.key
#     905         )
#     906     else:
#     907         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/household/income/spm_unit/spm_unit_benefits.py:40, in spm_unit_benefits.formula(spm_unit, period, parameters)
#      38 if not parameters(period).gov.hud.abolition:
#      39     BENEFITS.append("spm_unit_capped_housing_subsidy")
# ---> 40 return add(spm_unit, period, BENEFITS)
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:652, in Simulation._calculate(self, variable_name, period)
#     650         values = self._calculate(variable_name, contained_months[-1])
#     651     else:
# --> 652         values = self.calculate_add(variable_name, period)
#     653     alternate_period_handling = True
#     654 elif variable.definition_period == YEAR and period.unit == MONTH:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:67, in Microsimulation.calculate_add(self, variable_name, period, map_to, use_weights)
#      60 def calculate_add(
#      61     self,
#      62     variable_name: str,
#    (...)
#      65     use_weights: bool = True,
#      66 ) -> MicroSeries:
# ---> 67     values = super().calculate_add(variable_name, period, map_to)
#      68     if not use_weights:
#      69         return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:809, in Simulation.calculate_add(self, variable_name, period, decode_enums)
#     798 if variable.definition_period not in [
#     799     periods.DAY,
#     800     periods.MONTH,
#     801     periods.YEAR,
#     802 ]:
#     803     raise ValueError(
#     804         "Unable to sum constant variable '{}' over period {}: only variables defined daily, monthly, or yearly can be summed over time.".format(
#     805             variable.name, period
#     806         )
#     807     )
# --> 809 result = sum(
#     810     self.calculate(variable_name, sub_period)
#     811     for sub_period in period.get_subperiods(variable.definition_period)
#     812 )
#     813 holder = self.get_holder(variable.name)
#     814 holder.put_in_cache(result, period, self.branch_name)
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:810, in <genexpr>(.0)
#     798 if variable.definition_period not in [
#     799     periods.DAY,
#     800     periods.MONTH,
#     801     periods.YEAR,
#     802 ]:
#     803     raise ValueError(
#     804         "Unable to sum constant variable '{}' over period {}: only variables defined daily, monthly, or yearly can be summed over time.".format(
#     805             variable.name, period
#     806         )
#     807     )
#     809 result = sum(
# --> 810     self.calculate(variable_name, sub_period)
#     811     for sub_period in period.get_subperiods(variable.definition_period)
#     812 )
#     813 holder = self.get_holder(variable.name)
#     814 holder.put_in_cache(result, period, self.branch_name)
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/snap.py:27, in snap.formula(spm_unit, period, parameters)
#      25     return spm_unit("snap_reported", period) / MONTHS_IN_YEAR
#      26 else:
# ---> 27     value = add(
#      28         spm_unit,
#      29         period,
#      30         [
#      31             "snap_normal_allotment",
#      32             "snap_emergency_allotment",
#      33             "dc_snap_temporary_local_benefit",
#      34         ],
#      35     )
#      36     if is_in_microsim:
#      37         return value * takes_up
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/snap_normal_allotment.py:16, in snap_normal_allotment.formula(spm_unit, period, parameters)
#      13 def formula(spm_unit, period, parameters):
#      14     # Federal SNAP rules are defined in U.S.C Title 7, Chapter 51, which
#      15     # also defines state powers to modify the rules.
# ---> 16     eligible = spm_unit("is_snap_eligible", period)
#      17     expected_contribution = spm_unit("snap_expected_contribution", period)
#      18     max_allotment = spm_unit("snap_max_allotment", period)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/eligibility/is_snap_eligible.py:21, in is_snap_eligible.formula(spm_unit, period, parameters)
#      19 normal_eligibility = net & gross & asset
#      20 # Categorical eligibility (SSI, TANF, and BBCE TANF) overrides tests.
# ---> 21 categorical_eligibility = spm_unit(
#      22     "meets_snap_categorical_eligibility", period
#      23 )
#      24 return normal_eligibility | categorical_eligibility
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:657, in Simulation._calculate(self, variable_name, period)
#     655 alternate_period_handling = True
#     656 if variable.quantity_type == QuantityType.STOCK:
# --> 657     values = self._calculate(variable_name, period.this_year)
#     658 else:
#     659     values = self.calculate_divide(variable_name, period)
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/eligibility/meets_snap_categorical_eligibility.py:14, in meets_snap_categorical_eligibility.formula(spm_unit, period, parameters)
#      12 def formula(spm_unit, period, parameters):
#      13     programs = parameters(period).gov.usda.snap.categorical_eligibility
# ---> 14     return add(spm_unit, period, programs) > 0
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/hhs/tanf/non_cash/is_tanf_non_cash_eligible.py:13, in is_tanf_non_cash_eligible.formula(spm_unit, period, parameters)
#      11 def formula(spm_unit, period, parameters):
#      12     gross = spm_unit("meets_tanf_non_cash_gross_income_test", period)
# ---> 13     net = spm_unit("meets_tanf_non_cash_net_income_test", period)
#      14     asset = spm_unit("meets_tanf_non_cash_asset_test", period)
#      15     return gross & net & asset
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/hhs/tanf/non_cash/meets_tanf_non_cash_net_income_test.py:23, in meets_tanf_non_cash_net_income_test.formula(spm_unit, period, parameters)
#      19 net_limit_applies = where(
#      20     hheod, applies.hheod[state], applies.non_hheod[state]
#      21 ).astype(bool)
#      22 # All limits and incomes here expressed as % of FPG.
# ---> 23 net_income = spm_unit("snap_net_income_fpg_ratio", period)
#      24 net_limit = parameters(period).gov.usda.snap.income.limit.net
#      25 # Either the net limit doesn't apply or they pass it.
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:650, in Simulation._calculate(self, variable_name, period)
#     648 if variable.quantity_type == QuantityType.STOCK:
#     649     contained_months = period.get_subperiods(MONTH)
# --> 650     values = self._calculate(variable_name, contained_months[-1])
#     651 else:
#     652     values = self.calculate_add(variable_name, period)
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:966, in Simulation._run_formula(self, variable, population, period)
#     963 parameters_at = self.tax_benefit_system.parameters
#     965 if formula.__code__.co_argcount == 2:
# --> 966     array = formula(population, period)
#     967 else:
#     968     array = formula(population, period, parameters_at)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/income/snap_net_income_fpg_ratio.py:15, in snap_net_income_fpg_ratio.formula(spm_unit, period)
#      14 def formula(spm_unit, period):
# ---> 15     income = spm_unit("snap_net_income", period)
#      16     fpg = spm_unit("snap_fpg", period)
#      17     return income / fpg
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:966, in Simulation._run_formula(self, variable, population, period)
#     963 parameters_at = self.tax_benefit_system.parameters
#     965 if formula.__code__.co_argcount == 2:
# --> 966     array = formula(population, period)
#     967 else:
#     968     array = formula(population, period, parameters_at)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/income/snap_net_income.py:15, in snap_net_income.formula(spm_unit, period)
#      13 def formula(spm_unit, period):
#      14     gross_income = spm_unit("snap_gross_income", period)
# ---> 15     deductions = spm_unit("snap_deductions", period)
#      16     return max_(0, gross_income - deductions)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:903, in Simulation._run_formula(self, variable, population, period)
#     901 for added_variable in adds_list:
#     902     if added_variable in self.tax_benefit_system.variables:
# --> 903         values = values + self.calculate(
#     904             added_variable, period, map_to=variable.entity.key
#     905         )
#     906     else:
#     907         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:461, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     458 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     460 try:
# --> 461     result = self._calculate(variable_name, period)
#     462     if isinstance(result, EnumArray) and decode_enums:
#     463         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:686, in Simulation._calculate(self, variable_name, period)
#     684 try:
#     685     self._check_for_cycle(variable.name, period)
# --> 686     array = self._run_formula(variable, population, period)
#     688     # If no result, use the default value and cache it
#     689     if array is None:
#     690         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     966     array = formula(population, period)
#     967 else:
# --> 968     array = formula(population, period, parameters_at)
#     970 return array
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_us/variables/gov/usda/snap/income/deductions/snap_excess_medical_expense_deduction.py:29, in snap_excess_medical_expense_deduction.formula(spm_unit, period, parameters)
#      27 # Calculate standard medical deduction (SMD).
#      28 state = spm_unit.household("state_code_str", period)
# ---> 29 standard = p.standard[state]
#      30 standard_claimable = where(excess > 0, standard, 0)
#      31 # Return the greater of SMD and normal deduction.
#
# File ~/policyengine-core/policyengine_core/parameters/parameter_node_at_instant.py:58, in ParameterNodeAtInstant.__getitem__(self, key)
#      53 def __getitem__(
#      54     self, key: str
#      55 ) -> Union["ParameterNodeAtInstant", VectorialParameterNodeAtInstant]:
#      56     # If fancy indexing is used, cast to a vectorial node
#      57     if isinstance(key, numpy.ndarray):
# ---> 58         return parameters.VectorialParameterNodeAtInstant.build_from_node(
#      59             self
#      60         )[key]
#      61     return self._children[key]
#
# File ~/policyengine-core/policyengine_core/parameters/vectorial_parameter_node_at_instant.py:215, in VectorialParameterNodeAtInstant.__getitem__(self, key)
#     210         key = numpy.select(
#     211             [key == item.index for item in enum],
#     212             [item.name for item in enum],
#     213         )
#     214     else:
# --> 215         key = key.astype("str")
#     216 names = list(
#     217     self.dtype.names
#     218 )  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
#     219 default = numpy.full_like(
#     220     self.vector[key[0]], numpy.nan
#     221 )  # In case of unexpected key, we will set the corresponding value to NaN.
#
# KeyboardInterrupt:
