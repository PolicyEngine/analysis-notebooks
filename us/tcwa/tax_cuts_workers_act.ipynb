# %%
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
from policyengine_us.system import system
import pandas as pd
import plotly.graph_objects as go
from policyengine_core.charts import format_fig
import numpy as np
import csv

# %%
eitc_reform = Reform.from_dict({
  "gov.irs.credits.eitc.max[0].amount": {
    "2026-01-01.2026-12-31": 1502,
    "2027-01-01.2027-12-31": 1532,
    "2028-01-01.2028-12-31": 1563,
    "2029-01-01.2029-12-31": 1594,
    "2030-01-01.2030-12-31": 1626,
    "2031-01-01.2031-12-31": 1658,
    "2032-01-01.2032-12-31": 1691,
    "2033-01-01.2033-12-31": 1724,
    "2034-01-01.2034-12-31": 1758,
    "2035-01-01.2035-12-31": 1793
  },
  "gov.irs.credits.eitc.eligibility.age.max": {
    "2026-01-01.2100-12-31": np.inf
  },
  "gov.irs.credits.eitc.eligibility.age.min": {
    "2026-01-01.2100-12-31": 19
  },
  "gov.irs.credits.eitc.phase_in_rate[0].amount": {
    "2026-01-01.2100-12-31": 0.153
  },
  "gov.irs.credits.eitc.phase_out.rate[0].amount": {
    "2026-01-01.2100-12-31": 0.153
  },
  "gov.irs.credits.eitc.phase_out.start[0].amount": {
    "2026-01-01.2026-12-31": 11610,
    "2027-01-01.2027-12-31": 11842,
    "2028-01-01.2028-12-31": 12080,
    "2029-01-01.2029-12-31": 12318,
    "2030-01-01.2030-12-31": 12562,
    "2031-01-01.2031-12-31": 12806,
    "2032-01-01.2032-12-31": 13063,
    "2033-01-01.2033-12-31": 13320,
    "2034-01-01.2034-12-31": 13584,
    "2035-01-01.2035-12-31": 13854,
  },
    "gov.irs.credits.eitc.eligibility.age.min_student": {
      "2026-01-01.2100-12-31": 24
    },
    "gov.simulation.labor_supply_responses.elasticities.income": {
        "2024-01-01.2100-12-31": -0.05
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1": {
        "2024-01-01.2100-12-31": 0.31
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.2": {
        "2024-01-01.2100-12-31": 0.28
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.3": {
        "2024-01-01.2100-12-31": 0.27
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.4": {
        "2024-01-01.2100-12-31": 0.27
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.5": {
        "2024-01-01.2100-12-31": 0.25
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.6": {
        "2024-01-01.2100-12-31": 0.25
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.7": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.8": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.9": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.secondary": {
        "2024-01-01.2100-12-31": 0.27
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.10": {
        "2024-01-01.2100-12-31": 0.22
  },
}, country_id="us")

# %%
def calculate_total_budgetary_impact(reform, year):

    # For production code, use this line instead for the real dataset:
    # baseline = Microsimulation(dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5")
    # For compatibility with the example:
    baseline = Microsimulation(dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5")
    baseline_income_tax = baseline.calculate("income_tax", period=year).sum()

    reformed = Microsimulation(reform=reform, dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5")

    reformed_income_tax = reformed.calculate("income_tax", period=year).sum()

    impact = reformed_income_tax - baseline_income_tax
    return impact

# %%
def calculate_ten_year_projection(reform):
    results = []

    with open("eitc_reform_budgetary_impact.csv", "w", newline="") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(["Year", "Budgetary Impact"])

        for year in range(2026, 2036):
            print(f"Computing budgetary impact for year {year}...")
            impact = calculate_total_budgetary_impact(reform, year)
            results.append({"Year": year, "Budgetary Impact": impact})

            csvwriter.writerow([year, impact])
            print(f"Year {year} completed. Impact: ${impact/1e9:.2f} billion")

    print("All calculations complete. Results saved to 'eitc_reform_budgetary_impact.csv'")
    return pd.DataFrame(results)

# %%
def create_ten_year_bar_chart(df):
    # We invert the sign to show costs as positive numbers in the chart
    # This makes it more intuitive to read (higher bars = bigger costs)
    df["Budgetary Impact Billions"] = (-df["Budgetary Impact"] / 1e9).round(1)

    fig = go.Figure(
        go.Bar(
            x=df["Year"],
            y=df["Budgetary Impact Billions"],
            text=df["Budgetary Impact Billions"].apply(lambda x: f"${x:.1f}B"),
            textposition="auto",
            marker_color="#105293",
        )
    )

    fig.update_layout(
        title="10-Year Federal Budgetary Impact of the EITC Expansion",
        xaxis_title="Year",
        yaxis_title="Cost (Billions $)",
        xaxis=dict(tickmode="linear"),
        yaxis=dict(zeroline=True, zerolinewidth=2, zerolinecolor="Black"),
    )

    return format_fig(fig)

# %%
# Main execution
if __name__ == "__main__":
    print("Starting 10-year budgetary impact calculation for EITC expansion...")
    df_projection = calculate_ten_year_projection(eitc_reform)
    print("Calculation complete. Summary of results:")
    print(df_projection)


    print("Generating bar chart...")
    fig = create_ten_year_bar_chart(df_projection)
    fig.write_html("eitc_reform_impact_chart.html")
    print("Bar chart saved to 'eitc_reform_impact_chart.html'")
    
    # Optionally show the chart if running in an interactive environment
    fig.show()
    print("Analysis complete.")
# Out:
# Starting 10-year budgetary impact calculation for EITC expansion...
# Computing budgetary impact for year 2026...
# Year 2026 completed. Impact: $-17.49 billion
# Computing budgetary impact for year 2027...
# Year 2027 completed. Impact: $-17.46 billion
# Computing budgetary impact for year 2028...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 4
#       2 if __name__ == "__main__":
#       3     print("Starting 10-year budgetary impact calculation for EITC expansion...")
# ----> 4     df_projection = calculate_ten_year_projection(eitc_reform)
#       5     print("Calculation complete. Summary of results:")
#       6     print(df_projection)
#
# Cell In[16], line 10, in calculate_ten_year_projection(reform)
#       8 for year in range(2026, 2036):
#       9     print(f"Computing budgetary impact for year {year}...")
# ---> 10     impact = calculate_total_budgetary_impact(reform, year)
#      11     results.append({"Year": year, "Budgetary Impact": impact})
#      13     csvwriter.writerow([year, impact])
#
# Cell In[15], line 11, in calculate_total_budgetary_impact(reform, year)
#       7 baseline_income_tax = baseline.calculate("income_tax", period=year).sum()
#       9 reformed = Microsimulation(reform=reform, dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5")
# ---> 11 reformed_income_tax = reformed.calculate("income_tax", period=year).sum()
#      13 impact = reformed_income_tax - baseline_income_tax
#      14 return impact
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax.py:18, in income_tax.formula(person, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         person, period, ["income_tax_before_refundable_credits"]
#      20     )
#      21     subtracted_components = add(
#      22         person, period, ["income_tax_refundable_credits"]
#      23     )
#      24     return added_components - subtracted_components
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax_before_refundable_credits.py:18, in income_tax_before_refundable_credits.formula(tax_unit, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         tax_unit,
#      20         period,
#      21         [
#      22             "income_tax_before_credits",
#      23             "net_investment_income_tax",
#      24             "recapture_of_investment_credit",
#      25             "unreported_payroll_tax",
#      26             "qualified_retirement_penalty",
#      27         ],
#      28     )
#      29     subtracted_components = add(
#      30         tax_unit, period, ["income_tax_capped_non_refundable_credits"]
#      31     )
#      32     return added_components - subtracted_components
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/before_credits/income_tax_main_rates.py:14, in income_tax_main_rates.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
#      13     # compute taxable income that is taxed at the main rates
# ---> 14     full_taxable_income = tax_unit("taxable_income", period)
#      15     cg_exclusion = tax_unit(
#      16         "capital_gains_excluded_from_taxable_income", period
#      17     )
#      18     taxinc = max_(0, full_taxable_income - cg_exclusion)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/taxable_income.py:12, in taxable_income.formula(tax_unit, period, parameters)
#      11 def formula(tax_unit, period, parameters):
# ---> 12     agi = tax_unit("adjusted_gross_income", period)
#      13     exemptions = tax_unit("exemptions", period)
#      14     deductions = tax_unit("taxable_income_deductions", period)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/adjusted_gross_income.py:13, in adjusted_gross_income.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
# ---> 13     gross_income = add(tax_unit, period, ["irs_gross_income"])
#      14     above_the_line_deductions = tax_unit(
#      15         "above_the_line_deductions", period
#      16     )
#      17     agi = gross_income - above_the_line_deductions
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:186, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
# --> 186         entity.members(variable, period, options=options)
#     187     )
#     188 elif entity.entity.is_person:
#     189     raise ValueError(
#     190         f"You requested to aggregate {variable} (defined for {variable_entity.plural}) to {entity.entity.plural}, but this is not yet implemented."
#     191     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/irs_gross_income.py:19, in irs_gross_income.formula(person, period, parameters)
#      16 not_dependent = ~person("is_tax_unit_dependent", period)
#      17 for source in sources:
#      18     # Add positive values only - losses are deducted later.
# ---> 19     total += not_dependent * max_(0, add(person, period, [source]))
#      20 return total
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/irs_employment_income.py:13, in irs_employment_income.formula(person, period, parameters)
#      12 def formula(person, period, parameters):
# ---> 13     employment_income = person("employment_income", period)
#      14     pre_tax_contributions = person("pre_tax_contributions", period)
#      15     return max_(0, employment_income - pre_tax_contributions)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:251, in employment_income_behavioral_response.formula(person, period, parameters)
#     250 def formula(person, period, parameters):
# --> 251     lsr = person("labor_supply_behavioral_response", period)
#     252     employment_income = person("employment_income_before_lsr", period)
#     253     self_employment_income = person(
#     254         "self_employment_income_before_lsr", period
#     255     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:223, in labor_supply_behavioral_response.formula(person, period, parameters)
#     212     branch.set_input(
#     213         "employment_income_before_lsr",
#     214         period,
#     215         person("employment_income_before_lsr", period),
#     216     )
#     217     branch.set_input(
#     218         "self_employment_income_before_lsr",
#     219         period,
#     220         person("self_employment_income_before_lsr", period),
#     221     )
# --> 223 response = add(
#     224     person,
#     225     period,
#     226     [
#     227         "income_elasticity_lsr",
#     228         "substitution_elasticity_lsr",
#     229     ],
#     230 )
#     231 simulation = person.simulation
#     232 del simulation.branches["baseline"].branches[
#     233     "baseline_lsr_measurement"
#     234 ]
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:166, in substitution_elasticity_lsr.formula(person, period, parameters)
#     162 self_employment_income = person(
#     163     "self_employment_income_before_lsr", period
#     164 )
#     165 earnings = employment_income + self_employment_income
# --> 166 wage_change = person("relative_wage_change", period)
#     167 return (
#     168     earnings * wage_change * person("substitution_elasticity", period)
#     169 )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:54, in relative_wage_change.formula(person, period, parameters)
#      50 baseline_branch = simulation.get_branch("baseline").get_branch(
#      51     "baseline_lsr_measurement"
#      52 )
#      53 baseline_person = baseline_branch.populations["person"]
# ---> 54 baseline_mtr = baseline_person("marginal_tax_rate", period)
#      55 baseline_wage = 1 - baseline_mtr
#      56 measurement_branch = simulation.get_branch("lsr_measurement")
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/household/marginal_tax_rate.py:51, in marginal_tax_rate.formula(person, period, parameters)
#      44 alt_sim.set_input(
#      45     "self_employment_income",
#      46     period,
#      47     self_employment_income
#      48     + mask * delta * (1 - emp_self_emp_ratio),
#      49 )
#      50 alt_person = alt_sim.person
# ---> 51 netinc_alt = alt_person.household("household_net_income", period)
#      52 increase = netinc_alt - netinc_base
#      53 mtr_values += where(mask, 1 - increase / delta, 0)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# ...
#     199     values = entity.sum(person_shares)
#     200 if result is None:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/adjusted_gross_income.py:13, in adjusted_gross_income.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
# ---> 13     gross_income = add(tax_unit, period, ["irs_gross_income"])
#      14     above_the_line_deductions = tax_unit(
#      15         "above_the_line_deductions", period
#      16     )
#      17     agi = gross_income - above_the_line_deductions
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:186, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
# --> 186         entity.members(variable, period, options=options)
#     187     )
#     188 elif entity.entity.is_person:
#     189     raise ValueError(
#     190         f"You requested to aggregate {variable} (defined for {variable_entity.plural}) to {entity.entity.plural}, but this is not yet implemented."
#     191     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/irs_gross_income.py:19, in irs_gross_income.formula(person, period, parameters)
#      16 not_dependent = ~person("is_tax_unit_dependent", period)
#      17 for source in sources:
#      18     # Add positive values only - losses are deducted later.
# ---> 19     total += not_dependent * max_(0, add(person, period, [source]))
#      20 return total
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/social_security/taxable_social_security.py:12, in taxable_social_security.formula(person, period, parameters)
#      11 def formula(person, period, parameters):
# ---> 12     unit_tss = person.tax_unit("tax_unit_taxable_social_security", period)
#      13     # allocate unit_tss to head and spouse in proportion to social_security
#      14     ind_socsec = person("social_security", period)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/social_security/tax_unit_taxable_social_security.py:40, in tax_unit_taxable_social_security.formula(tax_unit, period, parameters)
#      30 # Cohabitating married couples filing separately receive a base
#      31 # and adjusted base amount of 0
#      32 base_amount = where(
#      33     separate & cohabitating,
#      34     p.threshold.base.separate_cohabitating,
#      35     p.threshold.base.main[filing_status],
#      36 )
#      37 adjusted_base_amount = where(
#      38     separate & cohabitating,
#      39     p.threshold.adjusted_base.separate_cohabitating,
# ---> 40     p.threshold.adjusted_base.main[filing_status],
#      41 )
#      43 under_first_threshold = combined_income < base_amount
#      44 under_second_threshold = combined_income < adjusted_base_amount
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/parameters/parameter_node_at_instant.py:58, in ParameterNodeAtInstant.__getitem__(self, key)
#      53 def __getitem__(
#      54     self, key: str
#      55 ) -> Union["ParameterNodeAtInstant", VectorialParameterNodeAtInstant]:
#      56     # If fancy indexing is used, cast to a vectorial node
#      57     if isinstance(key, numpy.ndarray):
# ---> 58         return parameters.VectorialParameterNodeAtInstant.build_from_node(
#      59             self
#      60         )[key]
#      61     return self._children[key]
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/parameters/vectorial_parameter_node_at_instant.py:222, in VectorialParameterNodeAtInstant.__getitem__(self, key)
#     216 names = list(
#     217     self.dtype.names
#     218 )  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
#     219 default = numpy.full_like(
#     220     self.vector[key[0]], numpy.nan
#     221 )  # In case of unexpected key, we will set the corresponding value to NaN.
# --> 222 conditions = [key == name for name in names]
#     223 values = [self.vector[name] for name in names]
#     224 result = numpy.select(conditions, values, default)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/parameters/vectorial_parameter_node_at_instant.py:222, in <listcomp>(.0)
#     216 names = list(
#     217     self.dtype.names
#     218 )  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
#     219 default = numpy.full_like(
#     220     self.vector[key[0]], numpy.nan
#     221 )  # In case of unexpected key, we will set the corresponding value to NaN.
# --> 222 conditions = [key == name for name in names]
#     223 values = [self.vector[name] for name in names]
#     224 result = numpy.select(conditions, values, default)
#
# KeyboardInterrupt:
